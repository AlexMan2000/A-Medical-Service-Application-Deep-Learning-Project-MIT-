# %%
import pandas as pd
data = pd.read_csv("./medical_knowledge_base.csv",delimiter=",",encoding="gbk")

# %%
# import json
# file = open("./medical.json","r",encoding="utf-8").readlines()
# index = 2
# for row in file[1:500]:
#     line = json.loads(row)
#     print(index,line["name"],line["get_prob"],line["easy_get"],line["get_way"],line["cured_prob"])
#     index+=1
data
# Out:
#                                          name  \
# 0                        alveolar proteinosis
# 1                                   pertussis
# 2                           benzene poisoning
# 3                        asthmatic bronchitis
# 4         adult respiratory distress syndrome
# ..                                        ...
# 669                       psoriatic arthritis
# 670          hereditary complement deficiency
# 671                     hereditary angioedema
# 672                              drug allergy
# 673  severe combined immunodeficiency disease
#
#                                                   desc  \
# 0    alveolar proteinosis (pap), also known as rose...
# 1    pertussis (whoopingcough) is an acute respirat...
# 2    benzene is an aromatic hydrocarbon compound ob...
# 3    asthmatoid bronchitis, also known as asthmatic...
# 4    adult respiratory distress syndrome, abbreviat...
# ..                                                 ...
# ...

# %% [markdown]
# #####

# %%
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-50-b7c74cbf5af0> in <module>
# ----> 1 import sklearn
#
# ~\anaconda3\lib\site-packages\sklearn\__init__.py in <module>
#      78     from . import _distributor_init  # noqa: F401
#      79     from . import __check_build  # noqa: F401
# ---> 80     from .base import clone
#      81     from .utils._show_versions import show_versions
#      82
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in <module>
#      19 from . import __version__
#      20 from ._config import get_config
# ---> 21 from .utils import _IS_32BIT
#      22 from .utils.validation import check_X_y
#      23 from .utils.validation import check_array
#
# ~\anaconda3\lib\site-packages\sklearn\utils\__init__.py in <module>
#      21
#      22 from .murmurhash import murmurhash3_32
# ...
