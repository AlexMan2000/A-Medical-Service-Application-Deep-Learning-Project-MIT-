# %%
import tensorflow

# %%
import SimpleITK as sitk

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns 

import os
import glob

##import SimpleITK as sitk

from PIL import Image

# from scipy.misc import imread

# %matplotlib inline
from IPython.display import clear_output
pd.options.mode.chained_assignment = None

# %%
annotations = pd.read_csv('./Dataset/annotations.csv')
candidates = pd.read_csv('./Dataset/candidates.csv')

# %%
annotations.head()
# Out:
#                                            seriesuid      coordX      coordY  \
# 0  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222... -128.699421 -175.319272
# 1  1.3.6.1.4.1.14519.5.2.1.6279.6001.100225287222...  103.783651 -211.925149
# 2  1.3.6.1.4.1.14519.5.2.1.6279.6001.100398138793...   69.639017 -140.944586
# 3  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...  -24.013824  192.102405
# 4  1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016...    2.441547  172.464881
#
#        coordZ  diameter_mm
# 0 -298.387506     5.651471
# 1 -227.121250     4.224708
# 2  876.374496     5.786348
# 3 -391.081276     8.143262
# 4 -405.493732    18.545150

# %%
class CTScan(object):
    def __init__(self, filename = None, coords = None):
        self.filename = filename
        self.coords = coords
        self.ds = None
        self.image = None

    def reset_coords(self, coords):
        self.coords = coords

    def read_mhd_image(self):
        path = glob.glob('/content/gdrive/My Drive/lungcancer/Dataset_LUNA_16/seg-lungs-LUNA16/*/'+ self.filename + '.mhd')
        self.ds = sitk.ReadImage(path[0])
        self.image = sitk.GetArrayFromImage(self.ds)

    def get_resolution(self):
        return self.ds.GetSpacing()

    def get_origin(self):
        return self.ds.GetOrigin()

    def get_ds(self):
        return self.ds

    def get_voxel_coords(self):
        origin = self.get_origin()
        resolution = self.get_resolution()
        voxel_coords = [np.absolute(self.coords[j]-origin[j])/resolution[j] \
            for j in range(len(self.coords))]
        return tuple(voxel_coords)
    
    def get_image(self):
        return self.image
    
    def get_subimage(self, width):
        self.read_mhd_image()
        x, y, z = self.get_voxel_coords()
        subImage = self.image[z, y-width/2:y+width/2, x-width/2:x+width/2]
        return subImage   
    def normalizePlanes(self, npzarray):
        maxHU = 400.
        minHU = -1000.
        npzarray = (npzarray - minHU) / (maxHU - minHU)
        npzarray[npzarray>1] = 1.
        npzarray[npzarray<0] = 0.
        return npzarray
    
    def save_image(self, filename, width):
        image = self.get_subimage(width)
        image = self.normalizePlanes(image)
        Image.fromarray(image*255).convert('L').save(filename)

# %%
import cv2
import scipy.misc

# %%
from PIL import ImageEnhance

class PreProcessing(object):
    def __init__(self, image = None):
        self.image = image
    
    def subtract_mean(self):
        self.image = (self.image/255.0 - 0.25)*255
        return self.image
    
    def downsample_data(self):
        self.image = cv2.resize(self.image, (40,40), interpolation = cv2.INTER_AREA)
        return self.image

    def upsample_data(self):
        self.image = cv2.resize(self.image, (224, 224), interpolation = cv2.INTER_CUBIC)
        return self.image

# %%
import h5py
h5f = h5py.File('./Dataset/traindataset.h5', 'r')
X_train_images = h5f['X']
Y_train_labels = h5f['Y']

h5f2 = h5py.File('./Dataset/valdataset.h5', 'r')
X_val_images = h5f2['X']
Y_val_labels = h5f2['Y']

# %%
# Preprocessing the training dataset
X_train_images_np = np.expand_dims(np.array(X_train_images), axis = 3)
y_train_labels_np = np.array(Y_train_labels)
X_val_images_np = np.expand_dims(np.array(X_val_images), axis = 3)
y_val_labels_np = np.array(Y_val_labels)

# %%
#Testing dataset
h5f2 = h5py.File('./Dataset/testdataset.h5', 'r')
X_test_images = h5f2['X']
Y_test_labels = h5f2['Y']

# %%
X_test_images_np = np.expand_dims(np.array(X_test_images), axis = 3)
y_test_labels_np = np.array(Y_test_labels)

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout,BatchNormalization,AveragePooling2D
from keras.optimizers import SGD
from keras.preprocessing.image import ImageDataGenerator

# %%
# Deep CNN model
def define_model():
	model = Sequential()
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(50, 50, 1)))
	model.add(BatchNormalization())
	model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.1))
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.2))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.3))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.4))
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
	model.add(BatchNormalization())
	model.add(MaxPooling2D((2, 2)))
	model.add(Dropout(0.5))
	model.add(Flatten())
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'))
	model.add(BatchNormalization())
	model.add(Dropout(0.5))
	model.add(Dense(128, activation='relu', kernel_initializer='he_uniform'));return model

mobile = define_model()

# %%
mobile.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 50, 50, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# =================================================================
# Total params: 914,144
# Trainable params: 911,968
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
op_layer = mobile.output
final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(op_layer)
final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(final_layer)
final_layer = Dense(2,activation= 'softmax')(final_layer)
from keras.models  import Model
# Define model input and output
model = Model(inputs = mobile.input , outputs = final_layer)
opt = SGD(lr=0.001, momentum=0.9)
import keras
optimizer_sgd = keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=optimizer_sgd, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-3ac5c5d1547a> in <module>
# ----> 1 op_layer = mobile.output
#       2 final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(op_layer)
#       3 final_layer = Dense(128,activation='relu',kernel_initializer='he_uniform')(final_layer)
#       4 final_layer = Dense(2,activation= 'softmax')(final_layer)
#       5 from keras.models  import Model
#
# NameError: name 'mobile' is not defined

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_input (InputLayer)    [(None, 50, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 50, 50, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 947,426
# Trainable params: 945,250
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
def summarize_diagnostics(hist):
	plt.plot(hist.history["accuracy"])
	plt.plot(hist.history['val_accuracy'])
	plt.plot(hist.history['loss'])
	plt.plot(hist.history['val_loss'])
	plt.title("model accuracy")
	plt.ylabel("Accuracy")
	plt.xlabel("Epoch")
	plt.legend(["Accuracy","Validation Accuracy","loss","Validation Loss"])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint('classification_deep_conv_model.h5', save_best_only=True),
    keras.callbacks.ReduceLROnPlateau()]

# %%
def run_test_harness():
	# create data generator
	datagen = ImageDataGenerator(width_shift_range=0.1, height_shift_range=0.1, horizontal_flip=True,zoom_range=0.1)
	# prepare iterator
	it_train = datagen.flow(X_train_images_np, y_train_labels_np, batch_size=64)
	# fit model
	steps = int(X_train_images_np.shape[0] / 64)
	hist = model.fit_generator(it_train, steps_per_epoch=steps, epochs=100, validation_data=(X_val_images_np, y_val_labels_np), verbose=1, callbacks = callbacks)
	# evaluate model
	_, acc = model.evaluate(X_val_images_np, y_val_labels_np, verbose=1)
	print('> %.3f' % (acc * 100.0))
	# learning curves
	summarize_diagnostics(hist)

# entry point, run the test harness
run_test_harness()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/100
# 81/81 [==============================] - 11s 48ms/step - loss: 0.5630 - accuracy: 0.8088 - val_loss: 0.4887 - val_accuracy: 0.8273
# Epoch 2/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.4593 - accuracy: 0.8366 - val_loss: 0.4338 - val_accuracy: 0.8273
# Epoch 3/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.4398 - accuracy: 0.8352 - val_loss: 0.4436 - val_accuracy: 0.8304
# Epoch 4/100
# 81/81 [==============================] - 3s 42ms/step - loss: 0.4272 - accuracy: 0.8388 - val_loss: 0.4156 - val_accuracy: 0.8311
# Epoch 5/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.4203 - accuracy: 0.8291 - val_loss: 0.4064 - val_accuracy: 0.8288
# Epoch 6/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3941 - accuracy: 0.8280 - val_loss: 0.3631 - val_accuracy: 0.8335
# Epoch 7/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.3700 - accuracy: 0.8421 - val_loss: 0.5078 - val_accuracy: 0.8273
# Epoch 8/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.4385 - accuracy: 0.8410 - val_loss: 0.4996 - val_accuracy: 0.8273
# Epoch 9/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.4475 - accuracy: 0.8290 - val_loss: 0.4134 - val_accuracy: 0.8281
# Epoch 10/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.4045 - accuracy: 0.8361 - val_loss: 0.3829 - val_accuracy: 0.8358
# Epoch 11/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3902 - accuracy: 0.8309 - val_loss: 0.3665 - val_accuracy: 0.8473
# Epoch 12/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3561 - accuracy: 0.8436 - val_loss: 0.3641 - val_accuracy: 0.8265
# Epoch 13/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3622 - accuracy: 0.8383 - val_loss: 0.3275 - val_accuracy: 0.8720
# Epoch 14/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3141 - accuracy: 0.8649 - val_loss: 0.3387 - val_accuracy: 0.8712
# Epoch 15/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.3179 - accuracy: 0.8517 - val_loss: 0.2924 - val_accuracy: 0.8859
# Epoch 16/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2893 - accuracy: 0.8778 - val_loss: 0.2713 - val_accuracy: 0.8928
# Epoch 17/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.2705 - accuracy: 0.8868 - val_loss: 0.2472 - val_accuracy: 0.9059
# Epoch 18/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.2465 - accuracy: 0.8983 - val_loss: 0.2360 - val_accuracy: 0.9036
# Epoch 19/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2502 - accuracy: 0.8928 - val_loss: 0.2316 - val_accuracy: 0.9121
# Epoch 20/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2771 - accuracy: 0.8804 - val_loss: 0.2976 - val_accuracy: 0.8720
# Epoch 21/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2869 - accuracy: 0.8823 - val_loss: 0.2474 - val_accuracy: 0.9021
# Epoch 22/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2587 - accuracy: 0.8951 - val_loss: 0.3087 - val_accuracy: 0.8404
# Epoch 23/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2495 - accuracy: 0.9105 - val_loss: 0.1989 - val_accuracy: 0.9198
# Epoch 24/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2203 - accuracy: 0.9149 - val_loss: 0.2082 - val_accuracy: 0.9167
# Epoch 25/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2301 - accuracy: 0.9039 - val_loss: 0.2327 - val_accuracy: 0.9075
# Epoch 26/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.2022 - accuracy: 0.9231 - val_loss: 0.2047 - val_accuracy: 0.9183
# Epoch 27/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2148 - accuracy: 0.9115 - val_loss: 0.2163 - val_accuracy: 0.9036
# Epoch 28/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.2077 - accuracy: 0.9180 - val_loss: 0.1731 - val_accuracy: 0.9291
# Epoch 29/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1895 - accuracy: 0.9269 - val_loss: 0.1942 - val_accuracy: 0.9268
# Epoch 30/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2059 - accuracy: 0.9227 - val_loss: 0.1858 - val_accuracy: 0.9252
# Epoch 31/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1816 - accuracy: 0.9289 - val_loss: 0.1927 - val_accuracy: 0.9198
# Epoch 32/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1852 - accuracy: 0.9365 - val_loss: 0.1554 - val_accuracy: 0.9375
# Epoch 33/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1708 - accuracy: 0.9253 - val_loss: 0.1831 - val_accuracy: 0.93521704
# Epoch 34/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1585 - accuracy: 0.9458 - val_loss: 0.1706 - val_accuracy: 0.9322
# Epoch 35/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1572 - accuracy: 0.9330 - val_loss: 0.1656 - val_accuracy: 0.9268
# Epoch 36/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1522 - accuracy: 0.9428 - val_loss: 0.1635 - val_accuracy: 0.9391
# Epoch 37/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1565 - accuracy: 0.9381 - val_loss: 0.1580 - val_accuracy: 0.9429
# Epoch 38/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1641 - accuracy: 0.9409 - val_loss: 0.1499 - val_accuracy: 0.9453
# Epoch 39/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1361 - accuracy: 0.9489 - val_loss: 0.1589 - val_accuracy: 0.9375
# Epoch 40/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1380 - accuracy: 0.9468 - val_loss: 0.1568 - val_accuracy: 0.9414
# Epoch 41/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1527 - accuracy: 0.9454 - val_loss: 0.1569 - val_accuracy: 0.9283
# Epoch 42/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1342 - accuracy: 0.9490 - val_loss: 0.1390 - val_accuracy: 0.9453
# Epoch 43/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1278 - accuracy: 0.9473 - val_loss: 0.1496 - val_accuracy: 0.9360
# Epoch 44/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1334 - accuracy: 0.9457 - val_loss: 0.1441 - val_accuracy: 0.9414
# Epoch 45/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1356 - accuracy: 0.9483 - val_loss: 0.1674 - val_accuracy: 0.9322
# Epoch 46/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1367 - accuracy: 0.9499 - val_loss: 0.1677 - val_accuracy: 0.9314
# Epoch 47/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1310 - accuracy: 0.9539 - val_loss: 0.1515 - val_accuracy: 0.9383
# Epoch 48/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1636 - accuracy: 0.9337 - val_loss: 0.1874 - val_accuracy: 0.9206
# Epoch 49/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1357 - accuracy: 0.9444 - val_loss: 0.1529 - val_accuracy: 0.9460
# Epoch 50/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1382 - accuracy: 0.9491 - val_loss: 0.3496 - val_accuracy: 0.8335
# Epoch 51/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1929 - accuracy: 0.9232 - val_loss: 0.1642 - val_accuracy: 0.9275
# Epoch 52/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1494 - accuracy: 0.9435 - val_loss: 0.1308 - val_accuracy: 0.9499
# Epoch 53/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1426 - accuracy: 0.9454 - val_loss: 0.1284 - val_accuracy: 0.9468
# Epoch 54/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1299 - accuracy: 0.9545 - val_loss: 0.1849 - val_accuracy: 0.9214
# Epoch 55/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.2164 - accuracy: 0.9170 - val_loss: 0.2100 - val_accuracy: 0.9144
# Epoch 56/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1900 - accuracy: 0.9261 - val_loss: 0.1635 - val_accuracy: 0.9375
# Epoch 57/100
# 81/81 [==============================] - 3s 36ms/step - loss: 0.1537 - accuracy: 0.9396 - val_loss: 0.1394 - val_accuracy: 0.9453
# Epoch 58/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1380 - accuracy: 0.9441 - val_loss: 0.1474 - val_accuracy: 0.9345
# Epoch 59/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1387 - accuracy: 0.9498 - val_loss: 0.3382 - val_accuracy: 0.8604
# Epoch 60/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2406 - accuracy: 0.9069 - val_loss: 0.1678 - val_accuracy: 0.9260
# Epoch 61/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1496 - accuracy: 0.9445 - val_loss: 0.2408 - val_accuracy: 0.8998
# Epoch 62/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.2182 - accuracy: 0.9119 - val_loss: 0.1822 - val_accuracy: 0.9244
# Epoch 63/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1786 - accuracy: 0.9322 - val_loss: 0.1382 - val_accuracy: 0.9414
# Epoch 64/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1459 - accuracy: 0.9426 - val_loss: 0.1231 - val_accuracy: 0.9483
# Epoch 65/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1379 - accuracy: 0.9462 - val_loss: 0.1243 - val_accuracy: 0.9483
# Epoch 66/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1543 - accuracy: 0.9430 - val_loss: 0.1267 - val_accuracy: 0.9445
# Epoch 67/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1223 - accuracy: 0.9524 - val_loss: 0.1225 - val_accuracy: 0.9522
# Epoch 68/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1321 - accuracy: 0.9482 - val_loss: 0.1214 - val_accuracy: 0.9522
# Epoch 69/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1333 - accuracy: 0.9526 - val_loss: 0.1230 - val_accuracy: 0.9483
# Epoch 70/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1310 - accuracy: 0.9478 - val_loss: 0.1256 - val_accuracy: 0.9460
# Epoch 71/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1248 - accuracy: 0.9500 - val_loss: 0.1201 - val_accuracy: 0.9499
# Epoch 72/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1240 - accuracy: 0.9494 - val_loss: 0.1204 - val_accuracy: 0.9522
# Epoch 73/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1246 - accuracy: 0.9531 - val_loss: 0.1153 - val_accuracy: 0.9537
# Epoch 74/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1203 - accuracy: 0.9545 - val_loss: 0.1163 - val_accuracy: 0.9530
# Epoch 75/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1083 - accuracy: 0.9564 - val_loss: 0.1203 - val_accuracy: 0.9499
# Epoch 76/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1127 - accuracy: 0.9612 - val_loss: 0.1174 - val_accuracy: 0.9530
# Epoch 77/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1040 - accuracy: 0.9634 - val_loss: 0.1368 - val_accuracy: 0.9406
# Epoch 78/100
# 81/81 [==============================] - 3s 33ms/step - loss: 0.1215 - accuracy: 0.9483 - val_loss: 0.1232 - val_accuracy: 0.9476
# Epoch 79/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1193 - accuracy: 0.9568 - val_loss: 0.1172 - val_accuracy: 0.9568
# Epoch 80/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1021 - accuracy: 0.9612 - val_loss: 0.1153 - val_accuracy: 0.9530
# Epoch 81/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1180 - accuracy: 0.9556 - val_loss: 0.1120 - val_accuracy: 0.9576
# Epoch 82/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1030 - accuracy: 0.9603 - val_loss: 0.1136 - val_accuracy: 0.9591
# Epoch 83/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1022 - accuracy: 0.9610 - val_loss: 0.1123 - val_accuracy: 0.9576
# Epoch 84/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1080 - accuracy: 0.9612 - val_loss: 0.1130 - val_accuracy: 0.9568
# Epoch 85/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0974 - accuracy: 0.9603 - val_loss: 0.1130 - val_accuracy: 0.9576
# Epoch 86/100
# 81/81 [==============================] - 3s 37ms/step - loss: 0.1107 - accuracy: 0.9585 - val_loss: 0.1120 - val_accuracy: 0.9584
# Epoch 87/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.1004 - accuracy: 0.9631 - val_loss: 0.1063 - val_accuracy: 0.9630
# Epoch 88/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.1010 - accuracy: 0.9612 - val_loss: 0.1098 - val_accuracy: 0.9599
# Epoch 89/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.1037 - accuracy: 0.9573 - val_loss: 0.1137 - val_accuracy: 0.9576
# Epoch 90/100
# 81/81 [==============================] - 3s 35ms/step - loss: 0.0982 - accuracy: 0.9605 - val_loss: 0.1114 - val_accuracy: 0.9545
# Epoch 91/100
# 81/81 [==============================] - 3s 36ms/step - loss: 0.0917 - accuracy: 0.9685 - val_loss: 0.1075 - val_accuracy: 0.9584
# Epoch 92/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0979 - accuracy: 0.9657 - val_loss: 0.1053 - val_accuracy: 0.9584
# Epoch 93/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.1010 - accuracy: 0.9614 - val_loss: 0.1083 - val_accuracy: 0.9561
# Epoch 94/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0915 - accuracy: 0.9661 - val_loss: 0.1067 - val_accuracy: 0.9607
# Epoch 95/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0960 - accuracy: 0.9657 - val_loss: 0.1063 - val_accuracy: 0.9591
# Epoch 96/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0907 - accuracy: 0.9616 - val_loss: 0.1081 - val_accuracy: 0.9584
# Epoch 97/100
# 81/81 [==============================] - 3s 34ms/step - loss: 0.0904 - accuracy: 0.9666 - val_loss: 0.1102 - val_accuracy: 0.9576
# Epoch 98/100
# 81/81 [==============================] - 3s 37ms/step - loss: 0.0924 - accuracy: 0.9651 - val_loss: 0.1060 - val_accuracy: 0.9591
# Epoch 99/100
# 81/81 [==============================] - 3s 36ms/step - loss: 0.0941 - accuracy: 0.9643 - val_loss: 0.1069 - val_accuracy: 0.9584
# Epoch 100/100
# 81/81 [==============================] - 3s 36ms/step - loss: 0.1010 - accuracy: 0.9619 - val_loss: 0.1057 - val_accuracy: 0.9591
# 41/41 [==============================] - 0s 7ms/step - loss: 0.1057 - accuracy: 0.9591
# > 95.914

# %%
import keras
model_new_1 = keras.models.load_model("classification_deep_conv_model.h5")

# %%
model_new_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_input (InputLayer)    [(None, 50, 50, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 50, 50, 32)        320
# _________________________________________________________________
# batch_normalization (BatchNo (None, 50, 50, 32)        128
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        9248
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 50, 50, 32)        128
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 25, 25, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 64)        36928
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 25, 25, 64)        256
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 12, 12, 128)       73856
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 12, 12, 128)       147584
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 12, 12, 128)       512
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         147584
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 6, 6, 128)         512
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 3, 3, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 3, 3, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 3, 3, 128)         147584
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 3, 3, 128)         512
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 1, 1, 128)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1, 1, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               16512
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               16512
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 947,426
# Trainable params: 945,250
# Non-trainable params: 2,176
# _________________________________________________________________

# %%
from sklearn.metrics import confusion_matrix,classification_report
y_pred = model_new_1.predict(X_test_images_np[:1])
y_p = np.argmax(y_pred,axis=1)
y_true = np.argmax(y_test_labels_np,axis=1)
print('confusion matrix')
print(confusion_matrix(y_true,y_p))
print(y_p)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4a065f0c373c> in <module>
#       1 from sklearn.metrics import confusion_matrix,classification_report
# ----> 2 y_pred = model_new_1.predict(X_test_images_np[:1])
#       3 y_p = np.argmax(y_pred,axis=1)
#       4 y_true = np.argmax(y_test_labels_np,axis=1)
#       5 print('confusion matrix')
#
# NameError: name 'model_new_1' is not defined
